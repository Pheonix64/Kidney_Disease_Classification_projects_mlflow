# %% [markdown]
# # Donwload data from gdrive

# %%
import gdown
url="https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3/view?usp=sharing"
file_id = url.split("/")[-2]
file_id
# Out:
# '1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3&confirm=t&uuid=db069569-1dc3-4ad5-8d75-8c01273e2bbb
# To: /home/phoenix64/Bureau/mlProjects/Kidney_Disease_Classification_projects_mlflow/research/kidney-CT-Scan-data.zip
# 100%|██████████| 57.7M/57.7M [00:30<00:00, 1.90MB/s]
# 'kidney-CT-Scan-data.zip'
